# %%
from ultralytics import YOLO, SAM

# %%
model = YOLO("yolo11n.pt")
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 7.24MB/s]

# %%
model.save('models/yolo_weights.pt')

# %%
model1 = SAM("sam2.1_b.pt")
model1.save('models/sam_weights.pt')
# Out:
# ...
# 100%|██████████| 154M/154M [00:24<00:00, 6.64MB/s]
