# %%
import torch
import os
from ultralytics import YOLO, SAM

# %% [markdown]
# ### Yolo11 & SAM2

# %%
save_dir = 'C:/Users/ADMIN/Desktop/ITDSIU21099_HoangVanManh/Fashion-Marketing-Automation-Solutions/models'
os.makedirs(save_dir, exist_ok=True)

# %%
yolo11 = YOLO("yolo11n.pt")
save_path = os.path.join(save_dir, "yolo_weights.pt")
yolo11.save(save_path)

# %%
yolo11.info()
# Out:
# YOLO11n summary: 319 layers, 2,624,080 parameters, 0 gradients, 6.6 GFLOPs
# (319, 2624080, 0, 6.614336)

# %%
sam2 = SAM("sam2.1_b.pt")
save_path2 = os.path.join(save_dir, "sam_weights.pt")
sam2.save(save_path2)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/sam2.1_b.pt to 'sam2.1_b.pt'...
# 100%|██████████| 154M/154M [00:39<00:00, 4.12MB/s]

# %%
sam2.info()
# Out:
# Model summary: 566 layers, 80,850,178 parameters, 80,850,178 gradients
# (566, 80850178, 80850178, 0.0)
