# %%
import torch
import os
from ultralytics import YOLO, SAM

# %% [markdown]
# ### Yolo11 & SAM

# %%
# !nvidia-smi
# Out:
# Thu Feb 20 19:14:17 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 572.16                 Driver Version: 572.16         CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3050 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   51C    P8             12W /   75W |     508MiB /   4096MiB |      3%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
save_dir = 'C:/Users/ADMIN/Desktop/ITDSIU21099_HoangVanManh/Fashion-Marketing-Automation-Solutions/models'
os.makedirs(save_dir, exist_ok=True)

# %%
yolo11 = YOLO("yolo11n.pt")
save_path = os.path.join(save_dir, "yolo_weights.pt")
yolo11.save(save_path)

# %%
yolo11.info()
# Out:
# YOLO11n summary: 319 layers, 2,624,080 parameters, 0 gradients, 6.6 GFLOPs
# (319, 2624080, 0, 6.614336)

# %% [markdown]
# ### SAM

# %%
# !wget -q https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
