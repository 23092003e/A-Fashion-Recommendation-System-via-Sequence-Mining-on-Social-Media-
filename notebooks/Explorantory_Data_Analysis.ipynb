# %% [markdown]
# ## Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the DataSet

# %%
df = pd.read_csv("../data/processed/posts.csv")
df.head()
# Out:
#    post_id                  timestamp   ownerUsername     type  \
# 0        1  2023-06-02 16:34:43+00:00       maryleest  Sidecar
# 1        2  2023-01-01 07:49:16+00:00  tinaabeysekara  Sidecar
# 2        3  2023-05-29 18:57:51+00:00       maryleest  Sidecar
# 3        4  2023-03-07 19:30:42+00:00  stephaniebroek  Sidecar
# 4        5  2023-05-23 21:11:12+00:00       maryleest  Sidecar
#
#                                              caption            hashtags  \
# 0  Cannes 2023 with @kilianparis 🤍 #KilianCannes ...        KilianCannes
# 1  As the clock struck midnight to ring in 2022, ...                 NaN
# 2  The famous stairs 🤎 Photo @gustave_durin   Dre...                 NaN
# 3  I visualized this moment so many times before....    CHANELFallWinter
# 4  Got to witness such historical moment in cinem...  CannesFilmFestival
#
#    likesCount  commentsCount  \
# 0       32070            142
# 1        6565             86
# 2       28936            123
# 3        4764            215
# 4       13379            123
#
#                                                image
# 0  https://scontent-ord5-1.cdninstagram.com/v/t51...
# 1  https://instagram.fyei4-1.fna.fbcdn.net/v/t51....
# 2  https://instagram.fpeg1-2.fna.fbcdn.net/v/t51....
# 3  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 4  https://instagram.fprg5-1.fna.fbcdn.net/v/t51....

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827 entries, 0 to 826
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   post_id        827 non-null    int64
#  1   timestamp      827 non-null    object
#  2   ownerUsername  827 non-null    object
#  3   type           827 non-null    object
#  4   caption        820 non-null    object
#  5   hashtags       474 non-null    object
#  6   likesCount     827 non-null    int64
#  7   commentsCount  827 non-null    int64
#  8   image          827 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 58.3+ KB

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# post_id            0
# timestamp          0
# ownerUsername      0
# type               0
# caption            7
# hashtags         353
# likesCount         0
# commentsCount      0
# image              0
# dtype: int64

# %%
print(df.describe())
# Out:
#          post_id    likesCount  commentsCount
# count  827.00000  8.270000e+02     827.000000
# mean   414.00000  5.256894e+05    1206.575574
# std    238.87863  1.770391e+06    5375.458118
# min      1.00000  9.000000e+00       0.000000
# 25%    207.50000  8.735000e+02      10.000000
# 50%    414.00000  4.244000e+03      46.000000
# 75%    620.50000  1.224755e+05     230.500000
# max    827.00000  1.382552e+07   83042.000000

# %%
corr_matrix = df[['likesCount', 'commentsCount']].corr()
print(corr_matrix)
# Out:
#                likesCount  commentsCount
# likesCount       1.000000       0.610951
# commentsCount    0.610951       1.000000

# %%
plt.figure(figsize=(6,4))
plt.scatter(df['likesCount'], df['commentsCount'])
plt.xlabel('Likes')
plt.ylabel('Comments')
plt.show()
