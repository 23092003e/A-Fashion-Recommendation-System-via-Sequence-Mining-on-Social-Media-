# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.sparse import csr_matrix
import implicit
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
post_path = r"C:\Users\ADMIN\Desktop\ITDSIU21099_HoangVanManh\Fashion-Marketing-Automation-Solutions\data\processed\posts.csv"
df = pd.read_csv(post_path)

# %%
#Drop column type, image and caption
df = df.drop(['type', 'image', 'caption', 'hashtags'], axis=1)
df.head()
# Out:
#    post_id                  timestamp   ownerUsername  likesCount  \
# 0        1  2023-06-02 16:34:43+00:00       maryleest       32070
# 1        2  2023-01-01 07:49:16+00:00  tinaabeysekara        6565
# 2        3  2023-05-29 18:57:51+00:00       maryleest       28936
# 3        4  2023-03-07 19:30:42+00:00  stephaniebroek        4764
# 4        5  2023-05-23 21:11:12+00:00       maryleest       13379
#
#    commentsCount
# 0            142
# 1             86
# 2            123
# 3            215
# 4            123
